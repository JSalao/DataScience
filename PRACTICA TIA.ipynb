# %%
#importar librerias
import pandas as pd
from pandas import DataFrame
import numpy as np
from csv import reader
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['figure.figsize'] = (10, 7)
plt.style.use('ggplot')

# %%
conda install seaborn
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
hola=' hola '
#print(hola.strip())
# Out:
# ' hola '

# %%
cabec= pd.read_csv('Dataset/features.txt', header=None,delimiter=' *, *', engine='python')

cabec.columns = ['Colum']
#cabec['act_reconocida']=dfl['act_reconocida'].astype(str)
cabec['Colum'].str.strip()
cabec.values
# Out:
# array([['tBodyAcc-Mean-1'],
#        ['tBodyAcc-Mean-2'],
#        ['tBodyAcc-Mean-3'],
#        ['tBodyAcc-STD-1'],
#        ['tBodyAcc-STD-2'],
#        ['tBodyAcc-STD-3'],
#        ['tBodyAcc-Mad-1'],
#        ['tBodyAcc-Mad-2'],
#        ['tBodyAcc-Mad-3'],
#        ['tBodyAcc-Max-1'],
#        ['tBodyAcc-Max-2'],
#        ['tBodyAcc-Max-3'],
#        ['tBodyAcc-Min-1'],
#        ['tBodyAcc-Min-2'],
#        ['tBodyAcc-Min-3'],
#        ['tBodyAcc-SMA-1'],
#        ['tBodyAcc-Energy-1'],
#        ['tBodyAcc-Energy-2'],
#        ['tBodyAcc-Energy-3'],
#        ['tBodyAcc-IQR-1'],
#        ['tBodyAcc-IQR-2'],
#        ['tBodyAcc-IQR-3'],
#        ['tBodyAcc-ropy-1'],
#        ['tBodyAcc-ropy-1'],
#        ['tBodyAcc-ropy-1'],
#        ['tBodyAcc-ARCoeff-1'],
#        ['tBodyAcc-ARCoeff-2'],
#        ['tBodyAcc-ARCoeff-3'],
#        ['tBodyAcc-ARCoeff-4'],
#        ['tBodyAcc-ARCoeff-5'],
#        ['tBodyAcc-ARCoeff-6'],
#        ['tBodyAcc-ARCoeff-7'],
# ...

# %%
cabec.values
# Out:
# array([['tBodyAcc-Mean-1'],
#        ['tBodyAcc-Mean-2'],
#        ['tBodyAcc-Mean-3'],
#        ['tBodyAcc-STD-1'],
#        ['tBodyAcc-STD-2'],
#        ['tBodyAcc-STD-3'],
#        ['tBodyAcc-Mad-1'],
#        ['tBodyAcc-Mad-2'],
#        ['tBodyAcc-Mad-3'],
#        ['tBodyAcc-Max-1'],
#        ['tBodyAcc-Max-2'],
#        ['tBodyAcc-Max-3'],
#        ['tBodyAcc-Min-1'],
#        ['tBodyAcc-Min-2'],
#        ['tBodyAcc-Min-3'],
#        ['tBodyAcc-SMA-1'],
#        ['tBodyAcc-Energy-1'],
#        ['tBodyAcc-Energy-2'],
#        ['tBodyAcc-Energy-3'],
#        ['tBodyAcc-IQR-1'],
#        ['tBodyAcc-IQR-2'],
#        ['tBodyAcc-IQR-3'],
#        ['tBodyAcc-ropy-1'],
#        ['tBodyAcc-ropy-1'],
#        ['tBodyAcc-ropy-1'],
#        ['tBodyAcc-ARCoeff-1'],
#        ['tBodyAcc-ARCoeff-2'],
#        ['tBodyAcc-ARCoeff-3'],
#        ['tBodyAcc-ARCoeff-4'],
#        ['tBodyAcc-ARCoeff-5'],
#        ['tBodyAcc-ARCoeff-6'],
#        ['tBodyAcc-ARCoeff-7'],
# ...

# %%
idte= pd.read_csv('Dataset/subject_id_test.txt', header=None)
idte.columns = ['id_sub']
ar= pd.read_csv('Dataset/y_test.txt', header=None)
ar.columns = ['act_reconocida']


data= pd.read_csv('Dataset/X_test.txt', sep=" ", header=None)
data.columns = cabec['Colum'].tolist() 
data
# Out:
#       tBodyAcc-Mean-1  tBodyAcc-Mean-2  tBodyAcc-Mean-3  tBodyAcc-STD-1  \
# 0            0.030914        -0.008927         0.040382       -0.938504
# 1            0.042548         0.001079        -0.026236       -0.975516
# 2            0.038297        -0.011660        -0.025643       -0.993922
# 3            0.036205        -0.018148        -0.025240       -0.994845
# 4            0.038034        -0.013437        -0.032899       -0.993955
# ...               ...              ...              ...             ...
# 3157         0.052279        -0.038687        -0.013494       -0.287933
# 3158         0.073745        -0.024673        -0.017836       -0.305455
# 3159         0.068334         0.043822        -0.024135       -0.329706
# 3160         0.023016         0.032345        -0.011830       -0.323182
# 3161        -0.010846        -0.004134        -0.037678       -0.330114
#
#       tBodyAcc-STD-2  tBodyAcc-STD-3  tBodyAcc-Mad-1  tBodyAcc-Mad-2  \
# ...

# %%
df = pd.concat([idte, ar, data], axis=1)
df
# Out:
#       id_sub  act_reconocida  tBodyAcc-Mean-1  tBodyAcc-Mean-2  \
# 0          2               5         0.030914        -0.008927
# 1          2               5         0.042548         0.001079
# 2          2               5         0.038297        -0.011660
# 3          2               5         0.036205        -0.018148
# 4          2               5         0.038034        -0.013437
# ...      ...             ...              ...              ...
# 3157      24               2         0.052279        -0.038687
# 3158      24               2         0.073745        -0.024673
# 3159      24               2         0.068334         0.043822
# 3160      24               2         0.023016         0.032345
# 3161      24               2        -0.010846        -0.004134
#
#       tBodyAcc-Mean-3  tBodyAcc-STD-1  tBodyAcc-STD-2  tBodyAcc-STD-3  \
# 0            0.040382       -0.938504       -0.944626       -0.759334
# ...

# %%
#cargar datos train
idtr= pd.read_csv('Dataset/subject_id_train.txt', header=None)
idtr.columns = ['id_sub']
ar1= pd.read_csv('Dataset/y_train.txt', header=None)
ar1.columns = ['act_reconocida']
data1= pd.read_csv('Dataset/X_train.txt', sep=" ", header=None)
data1.columns = cabec['Colum'].tolist()

# %%
print(cabec['Colum'].tolist() )
# Out:
# ['tBodyAcc-Mean-1', 'tBodyAcc-Mean-2', 'tBodyAcc-Mean-3', 'tBodyAcc-STD-1', 'tBodyAcc-STD-2', 'tBodyAcc-STD-3', 'tBodyAcc-Mad-1', 'tBodyAcc-Mad-2', 'tBodyAcc-Mad-3', 'tBodyAcc-Max-1', 'tBodyAcc-Max-2', 'tBodyAcc-Max-3', 'tBodyAcc-Min-1', 'tBodyAcc-Min-2', 'tBodyAcc-Min-3', 'tBodyAcc-SMA-1', 'tBodyAcc-Energy-1', 'tBodyAcc-Energy-2', 'tBodyAcc-Energy-3', 'tBodyAcc-IQR-1', 'tBodyAcc-IQR-2', 'tBodyAcc-IQR-3', 'tBodyAcc-ropy-1', 'tBodyAcc-ropy-1', 'tBodyAcc-ropy-1', 'tBodyAcc-ARCoeff-1', 'tBodyAcc-ARCoeff-2', 'tBodyAcc-ARCoeff-3', 'tBodyAcc-ARCoeff-4', 'tBodyAcc-ARCoeff-5', 'tBodyAcc-ARCoeff-6', 'tBodyAcc-ARCoeff-7', 'tBodyAcc-ARCoeff-8', 'tBodyAcc-ARCoeff-9', 'tBodyAcc-ARCoeff-10', 'tBodyAcc-ARCoeff-11', 'tBodyAcc-ARCoeff-12', 'tBodyAcc-Correlation-1', 'tBodyAcc-Correlation-2', 'tBodyAcc-Correlation-3', 'tGravityAcc-Mean-1', 'tGravityAcc-Mean-2', 'tGravityAcc-Mean-3', 'tGravityAcc-STD-1', 'tGravityAcc-STD-2', 'tGravityAcc-STD-3', 'tGravityAcc-Mad-1', 'tGravityAcc-Mad-2', 'tGravityAcc-Mad
# ...

# %%
df1 = pd.concat([idtr, ar1, data1], axis=1)
df1
# Out:
#       id_sub  act_reconocida  tBodyAcc-Mean-1  tBodyAcc-Mean-2  \
# 0          1               5         0.043580        -0.005970
# 1          1               5         0.039480        -0.002131
# 2          1               5         0.039978        -0.005153
# 3          1               5         0.039785        -0.011809
# 4          1               5         0.038758        -0.002289
# ...      ...             ...              ...              ...
# 7762      30               2         0.048048        -0.042445
# 7763      30               2         0.037639         0.006430
# 7764      30               2         0.037451        -0.002724
# 7765      30               2         0.044011        -0.004536
# 7766      30               2         0.068954         0.001810
#
#       tBodyAcc-Mean-3  tBodyAcc-STD-1  tBodyAcc-STD-2  tBodyAcc-STD-3  \
# 0           -0.035054       -0.995381       -0.988366       -0.937382
# ...

# %%
dfl = pd.concat([df, df1])
dfl
# Out:
#       id_sub  act_reconocida  tBodyAcc-Mean-1  tBodyAcc-Mean-2  \
# 0          2               5         0.030914        -0.008927
# 1          2               5         0.042548         0.001079
# 2          2               5         0.038297        -0.011660
# 3          2               5         0.036205        -0.018148
# 4          2               5         0.038034        -0.013437
# ...      ...             ...              ...              ...
# 7762      30               2         0.048048        -0.042445
# 7763      30               2         0.037639         0.006430
# 7764      30               2         0.037451        -0.002724
# 7765      30               2         0.044011        -0.004536
# 7766      30               2         0.068954         0.001810
#
#       tBodyAcc-Mean-3  tBodyAcc-STD-1  tBodyAcc-STD-2  tBodyAcc-STD-3  \
# 0            0.040382       -0.938504       -0.944626       -0.759334
# ...

# %% [markdown]
# <h3>Estadistica descriptiva

# %%
print(dfl.dtypes)
# Out:
# id_sub                               int64
# act_reconocida                       int64
# tBodyAcc-Mean-1                    float64
# tBodyAcc-Mean-2                    float64
# tBodyAcc-Mean-3                    float64
#                                     ...
# tBodyGyro-AngleWRTGravity-1        float64
# tBodyGyroJerk-AngleWRTGravity-1    float64
# tXAxisAcc-AngleWRTGravity-1        float64
# tYAxisAcc-AngleWRTGravity-1        float64
# tZAxisAcc-AngleWRTGravity-1        float64
# Length: 563, dtype: object

# %%
dfl['id_sub']=dfl['id_sub'].astype(str)
dfl['act_reconocida']=dfl['act_reconocida'].astype(str)

# %%
dfl.describe()
# Out:
#        tBodyAcc-Mean-1  tBodyAcc-Mean-2  tBodyAcc-Mean-3  tBodyAcc-STD-1  \
# count     10929.000000     10929.000000     10929.000000    10929.000000
# mean          0.039271        -0.000950        -0.018530       -0.602128
# std           0.101868         0.100673         0.088223        0.431281
# min          -1.000000        -1.000000        -1.000000       -1.000000
# 25%           0.031874        -0.011334        -0.028568       -0.991588
# 50%           0.038939        -0.002859        -0.019558       -0.896268
# 75%           0.043908         0.004553        -0.011525       -0.253824
# max           1.000000         1.000000         1.000000        1.000000
#
#        tBodyAcc-STD-2  tBodyAcc-STD-3  tBodyAcc-Mad-1  tBodyAcc-Mad-2  \
# count    10929.000000    10929.000000    10929.000000    10929.000000
# mean        -0.633645       -0.697054       -0.627605       -0.656793
# std          0.365457        0.311368        0.407387        0.346456
# ...

# %%
actividades = pd.read_csv('Dataset/activity_labels.txt',header=None, sep=" ")
actividades.columns = ['act_reconocida', 'des_act', 't_act']
#actividades['act_reconocida']=actividades['act_reconocida'].astype(str)
actividades.dtypes
# Out:
# act_reconocida     int64
# des_act           object
# t_act             object
# dtype: object

# %%
xact = pd.merge( actividades, dfl.loc[:,['act_reconocida', 'id_sub']])

# %%
xact
# Out:
#        act_reconocida       des_act     t_act  id_sub
# 0                   1       WALKING  Dinamica       2
# 1                   1       WALKING  Dinamica       2
# 2                   1       WALKING  Dinamica       2
# 3                   1       WALKING  Dinamica       2
# 4                   1       WALKING  Dinamica       2
# ...               ...           ...       ...     ...
# 10924              12  LIE_TO_STAND       NaN      28
# 10925              12  LIE_TO_STAND       NaN      29
# 10926              12  LIE_TO_STAND       NaN      29
# 10927              12  LIE_TO_STAND       NaN      30
# 10928              12  LIE_TO_STAND       NaN      30
#
# [10929 rows x 4 columns]

# %%
xact.dtypes
# Out:
# act_reconocida    object
# des_act           object
# id_sub            object
# dtype: object

# %%
print(xact.groupby('des_act').size())
# Out:
# des_act
# LAYING                1958
# LIE_TO_SIT              85
# LIE_TO_STAND            84
# SITTING               1801
# SIT_TO_LIE             107
# SIT_TO_STAND            33
# STANDING              1979
# STAND_TO_LIE           139
# STAND_TO_SIT            70
# WALKING               1722
# WALKING_DOWNSTAIRS    1407
# WALKING_UPSTAIRS      1544
# dtype: int64

# %%
agr_act = xact.groupby(by=["id_sub",'des_act']).count()
agr_act = agr_act.reset_index()
agr_act
# Out:
#     id_sub             des_act  act_reconocida
# 0        1              LAYING              48
# 1        1          LIE_TO_SIT               3
# 2        1        LIE_TO_STAND               3
# 3        1             SITTING              47
# 4        1          SIT_TO_LIE               4
# ..     ...                 ...             ...
# 344      9        STAND_TO_LIE               4
# 345      9        STAND_TO_SIT               1
# 346      9             WALKING              52
# 347      9  WALKING_DOWNSTAIRS              42
# 348      9    WALKING_UPSTAIRS              49
#
# [349 rows x 3 columns]

# %%
print(agr_act.dtypes)
# Out:
# id_sub            object
# des_act           object
# act_reconocida     int64
# dtype: object

# %%
actxid= agr_act.groupby(by=["id_sub"]).count()
actxid =actxid.reset_index()

# %%
actxid=actxid.loc[:,['id_sub','des_act']]
actxid
# Out:
#    id_sub  des_act
# 0       1       12
# 1      10       11
# 2      11       12
# 3      12       12
# 4      13       12
# 5      14       12
# 6      15       12
# 7      16       11
# 8      17       12
# 9      18       12
# 10     19       12
# 11      2       12
# 12     20       12
# 13     21       12
# 14     22       11
# 15     23       12
# 16     24       11
# 17     25       12
# 18     26       12
# 19     27       11
# 20     28       10
# 21     29       12
# 22      3       12
# 23     30       12
# 24      4       12
# 25      5       12
# 26      6       12
# 27      7       10
# 28      8       11
# 29      9       11

# %%
actxid.groupby('des_act').count()['id_sub'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='des_act'>

# %%
agr_act.groupby('des_act').count()['id_sub'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='des_act'>

# %%
xact.groupby('des_act').count()['id_sub'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='des_act'>

# %%
print(agr_act.dtypes)
# Out:
# id_sub            object
# des_act           object
# act_reconocida     int64
# dtype: object

# %%
actxid= agr_act.groupby(by=["id_sub"]).count()
agr_act
#dataframe1 = pd.pivot_table(agr_act, index=['id_sub'], columns=['des_act'], aggfunc=['act_reconocida'])
#dataframe1
# Out:
#     id_sub             des_act  act_reconocida
# 0        1              LAYING              48
# 1        1          LIE_TO_SIT               3
# 2        1        LIE_TO_STAND               3
# 3        1             SITTING              47
# 4        1          SIT_TO_LIE               4
# ..     ...                 ...             ...
# 344      9        STAND_TO_LIE               4
# 345      9        STAND_TO_SIT               1
# 346      9             WALKING              52
# 347      9  WALKING_DOWNSTAIRS              42
# 348      9    WALKING_UPSTAIRS              49
#
# [349 rows x 3 columns]

# %%
print(v1.dtypes)
# Out:
# LAYING                float64
# LIE_TO_SIT            float64
# LIE_TO_STAND          float64
# SITTING               float64
# SIT_TO_LIE            float64
# SIT_TO_STAND          float64
# STANDING              float64
# STAND_TO_LIE          float64
# STAND_TO_SIT          float64
# WALKING               float64
# WALKING_DOWNSTAIRS    float64
# WALKING_UPSTAIRS      float64
# dtype: object

# %%
v1= agr_act.pivot_table(
        index=['id_sub'], 
         columns='des_act', 
         values='act_reconocida'
).reset_index()
v1.index.name = v1.columns.name = None

# %%
v1['id_sub']=v1['id_sub'].astype(int)
v1 = v1.sort_values('id_sub')
v1.set_index('id_sub', inplace=True)

# %%
v1
# Out:
#         LAYING  LIE_TO_SIT  LIE_TO_STAND  SITTING  SIT_TO_LIE  SIT_TO_STAND  \
# id_sub
# 1         48.0         3.0           3.0     47.0         4.0           2.0
# 2         49.0         4.0           2.0     46.0         3.0           2.0
# 3         63.0         4.0           2.0     52.0         2.0           1.0
# 4         52.0         4.0           2.0     49.0         4.0           2.0
# 5         51.0         5.0           2.0     43.0         5.0           1.0
# 6         56.0         2.0           3.0     56.0         2.0           1.0
# 7         50.0         1.0           3.0     47.0         4.0           NaN
# 8         55.0         3.0           1.0     45.0         2.0           NaN
# 9         54.0         2.0           2.0     53.0         3.0           NaN
# 10        59.0         1.0           1.0     55.0         2.0           NaN
# 11        58.0         3.0           3.0     54.0         3.0           2.0
# ...

# %%
plt.figure(figsize=(16, 16))


sb.heatmap(v1, annot=True, )
# Out:
# <AxesSubplot:ylabel='id_sub'>

# %%
print(dfl.groupby('id_sub').size())
# Out:
# id_sub
# 1     368
# 10    306
# 11    337
# 12    340
# 13    348
# 14    346
# 15    351
# 16    379
# 17    401
# 18    403
# 19    381
# 2     324
# 20    384
# 21    434
# 22    335
# 23    392
# 24    410
# 25    434
# 26    409
# 27    394
# 28    395
# 29    364
# 3     359
# 30    409
# 4     336
# 5     324
# 6     342
# 7     318
# 8     295
# 9     311
# dtype: int64

# %%
xact1 = xact


xact1['act_reconocida'] = xact1['act_reconocida'].astype(int)
xact1['id_sub'] = xact1['id_sub'].astype(int)
xact1.dtypes
# Out:
# act_reconocida     int32
# des_act           object
# id_sub             int32
# dtype: object

# %%
serie = pd.Series(dfl.max())
maximos=(pd.DataFrame(serie, columns=['descip']))
maximos["descip"] = maximos["descip"].astype(str)
maximos["descip"].str.split(' ', expand=True)
# Out:
# C:\Users\vane_\AppData\Local\Temp/ipykernel_11380/2055844273.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   serie = pd.Series(dfl.max())
#                                    0
# tBodyAcc-Mean-1                  1.0
# tBodyAcc-Mean-2                  1.0
# tBodyAcc-Mean-3                  1.0
# tBodyAcc-STD-1                   1.0
# tBodyAcc-STD-2                   1.0
# ...                              ...
# tBodyGyro-AngleWRTGravity-1      1.0
# tBodyGyroJerk-AngleWRTGravity-1  1.0
# tXAxisAcc-AngleWRTGravity-1      1.0
# tYAxisAcc-AngleWRTGravity-1      1.0
# tZAxisAcc-AngleWRTGravity-1      1.0
#
# [561 rows x 1 columns]

# %%
dfl
dfl['act_reconocida']=dfl['act_reconocida'].astype(int)

# %%
dfl.dtypes
# Out:
# act_reconocida                       int32
# tBodyAcc-Mean-1                    float64
# tBodyAcc-Mean-2                    float64
# tBodyAcc-Mean-3                    float64
# tBodyAcc-STD-1                     float64
#                                     ...
# tBodyGyro-AngleWRTGravity-1        float64
# tBodyGyroJerk-AngleWRTGravity-1    float64
# tXAxisAcc-AngleWRTGravity-1        float64
# tYAxisAcc-AngleWRTGravity-1        float64
# tZAxisAcc-AngleWRTGravity-1        float64
# Length: 562, dtype: object

# %%
example = pd.DataFrame({'column 1': [0, 1, 0, 1], 
                        'column 2': [1, 0, 1, 0],
                        'column 3': [1, 1, 0, 0]})

for x, col in enumerate(example.columns):
    for y, ind in enumerate(example.index):
        if example.loc[ind, col]:
            plt.plot(x, y, 'o', color='red')
            
plt.xticks(range(len(example.columns)), labels=example.columns)
plt.yticks(range(len(example)), labels=example.index)
    
plt.show()

# %%
dscat =dfl.drop()
dscat
# Out:
#         act_reconocida  tBodyAcc-Mean-1  tBodyAcc-Mean-2  tBodyAcc-Mean-3  \
# id_sub
# 2                    5         0.030914        -0.008927         0.040382
# 2                    5         0.042548         0.001079        -0.026236
# 2                    5         0.038297        -0.011660        -0.025643
# 2                    5         0.036205        -0.018148        -0.025240
# 2                    5         0.038034        -0.013437        -0.032899
# ...                ...              ...              ...              ...
# 30                   2         0.048048        -0.042445        -0.065884
# 30                   2         0.037639         0.006430        -0.044345
# 30                   2         0.037451        -0.002724         0.021009
# 30                   2         0.044011        -0.004536        -0.051242
# 30                   2         0.068954         0.001810        -0.080323
#
# ...

# %%
dfl
# Out:
#                 id_sub  tBodyAcc-Mean-1  tBodyAcc-Mean-2  tBodyAcc-Mean-3  \
# act_reconocida
# 5                    2         0.030914        -0.008927         0.040382
# 5                    2         0.042548         0.001079        -0.026236
# 5                    2         0.038297        -0.011660        -0.025643
# 5                    2         0.036205        -0.018148        -0.025240
# 5                    2         0.038034        -0.013437        -0.032899
# ...                ...              ...              ...              ...
# 2                   30         0.048048        -0.042445        -0.065884
# 2                   30         0.037639         0.006430        -0.044345
# 2                   30         0.037451        -0.002724         0.021009
# 2                   30         0.044011        -0.004536        -0.051242
# 2                   30         0.068954         0.001810        -0.080323
#
# ...

# %%
fe_act = df1.drop(columns=['id_sub'])
#fe_act['act_reconocida']=fe_act['act_reconocida'].astype(str)
fe_act
# Out:
#       act_reconocida  tBodyAcc-Mean-1  tBodyAcc-Mean-2  tBodyAcc-Mean-3  \
# 0                  5         0.043580        -0.005970        -0.035054
# 1                  5         0.039480        -0.002131        -0.029067
# 2                  5         0.039978        -0.005153        -0.022651
# 3                  5         0.039785        -0.011809        -0.028916
# 4                  5         0.038758        -0.002289        -0.023863
# ...              ...              ...              ...              ...
# 7762               2         0.048048        -0.042445        -0.065884
# 7763               2         0.037639         0.006430        -0.044345
# 7764               2         0.037451        -0.002724         0.021009
# 7765               2         0.044011        -0.004536        -0.051242
# 7766               2         0.068954         0.001810        -0.080323
#
#       tBodyAcc-STD-1  tBodyAcc-STD-2  tBodyAcc-STD-3  tBodyAcc-Mad-1  \
# ...

# %%
fe_act.set_index('act_reconocida', inplace=True)

# %%
fe_act
# Out:
#       act_reconocida  tBodyAcc-Mean-1  tBodyAcc-Mean-2  tBodyAcc-Mean-3  \
# 0                  5         0.043580        -0.005970        -0.035054
# 1                  5         0.039480        -0.002131        -0.029067
# 2                  5         0.039978        -0.005153        -0.022651
# 3                  5         0.039785        -0.011809        -0.028916
# 4                  5         0.038758        -0.002289        -0.023863
# ...              ...              ...              ...              ...
# 7762               2         0.048048        -0.042445        -0.065884
# 7763               2         0.037639         0.006430        -0.044345
# 7764               2         0.037451        -0.002724         0.021009
# 7765               2         0.044011        -0.004536        -0.051242
# 7766               2         0.068954         0.001810        -0.080323
#
#       tBodyAcc-STD-1  tBodyAcc-STD-2  tBodyAcc-STD-3  tBodyAcc-Mad-1  \
# ...

# %%
prome1 = fe_act.groupby(by=["act_reconocida"]).mean()
prome1 = prome1.reset_index()
prome1
# Out:
#     act_reconocida  tBodyAcc-Mean-1  tBodyAcc-Mean-2  tBodyAcc-Mean-3  \
# 0                1         0.038610        -0.003473        -0.019730
# 1                2         0.032830        -0.012250        -0.027092
# 2                3         0.043449        -0.002116        -0.017834
# 3                4         0.037438         0.001972        -0.018468
# 4                5         0.040014        -0.001464        -0.019198
# 5                6         0.035454        -0.004054        -0.018190
# 6                7        -0.016196         0.067546         0.035108
# 7                8         0.061927        -0.419442        -0.270599
# 8                9        -0.363518         0.385396         0.224864
# 9               10         0.617409        -0.353166        -0.268588
# 10              11        -0.283950         0.431460         0.344822
# 11              12         0.618620        -0.356904        -0.358875
#
# ...

# %%
prome = fe_act.groupby(by=["act_reconocida"]).mean()
prome = prome.reset_index()
prome_si = prome
prome.set_index('act_reconocida', inplace=True)

# %%
prome= prome.transpose()

# %%
prome.dtypes
# Out:
# act_reconocida                       int64
# tBodyAcc-Mean-1                    float64
# tBodyAcc-Mean-2                    float64
# tBodyAcc-Mean-3                    float64
# tBodyAcc-STD-1                     float64
#                                     ...
# tBodyGyro-AngleWRTGravity-1        float64
# tBodyGyroJerk-AngleWRTGravity-1    float64
# tXAxisAcc-AngleWRTGravity-1        float64
# tYAxisAcc-AngleWRTGravity-1        float64
# tZAxisAcc-AngleWRTGravity-1        float64
# Length: 562, dtype: object

# %% [markdown]
# ## PIVOT PARA RELACION DE FEATURE CON ACTIV

# %% [markdown]
# v2= agr_act.pivot_table(
#         index=['id_sub'],
#          columns='des_act',
#          values='act_reconocida'
# ).reset_index()
# v2.index.name = v2.columns.name = None

# %% [markdown]
# v1['id_sub']=v1['id_sub'].astype(int)
# v1 = v1.sort_values('id_sub')
# v1.set_index('id_sub', inplace=True)

# %%
prome
# Out:
#                 tBodyAcc-Mean-1  tBodyAcc-Mean-2  tBodyAcc-Mean-3  \
# act_reconocida
# 1                      0.038610        -0.003473        -0.019730
# 2                      0.032830        -0.012250        -0.027092
# 3                      0.043449        -0.002116        -0.017834
# 4                      0.037438         0.001972        -0.018468
# 5                      0.040014        -0.001464        -0.019198
# 6                      0.035454        -0.004054        -0.018190
# 7                     -0.016196         0.067546         0.035108
# 8                      0.061927        -0.419442        -0.270599
# 9                     -0.363518         0.385396         0.224864
# 10                     0.617409        -0.353166        -0.268588
# 11                    -0.283950         0.431460         0.344822
# 12                     0.618620        -0.356904        -0.358875
#
#                 tBodyAcc-STD-1  tBodyAcc-STD-2  tBodyAcc-STD-3  \
# act_reconocida
# ...

# %% [markdown]
# fig = plt.figure(figsize=(14,14))
# plt.scatter(prome.column,prome.index)
# ##plt.plot(dfl['tBodyAcc-Mean-1'],dfl['act_reconocida'])
# plt.xlabel('Number of Images')
# plt.ylabel('Computational Hours')
# plt.grid()

# %%
example
# Out:
#    column 1  column 2  column 3
# 0         0         1         1
# 1         1         0         1
# 2         0         1         0
# 3         1         0         0

# %%
plt.figure(figsize=(16, 30))


sb.heatmap(prome, annot=True, )
# Out:
# <AxesSubplot:xlabel='act_reconocida'>

# %%
x =fe_act['act_reconocida']
y= fe_act['fBodyAccJerk-BandsEnergyOld-42']
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## fig, ax = plt.subplots()
# ax.violinplot(fe_act['act_reconocida'])
# plt.show()

# %%
fig, ax = plt.subplots()
ax.violinplot(dataset=prome)
plt.show()

# %%
fe_act.dtypes
# Out:
# act_reconocida                       int64
# tBodyAcc-Mean-1                    float64
# tBodyAcc-Mean-2                    float64
# tBodyAcc-Mean-3                    float64
# tBodyAcc-STD-1                     float64
#                                     ...
# tBodyGyro-AngleWRTGravity-1        float64
# tBodyGyroJerk-AngleWRTGravity-1    float64
# tXAxisAcc-AngleWRTGravity-1        float64
# tYAxisAcc-AngleWRTGravity-1        float64
# tZAxisAcc-AngleWRTGravity-1        float64
# Length: 562, dtype: object

# %%
x=fe_act['act_reconocida']
y = fe_act['tBodyAcc-Mean-1']
sb.violinplot(x=x,y=y,data=fe_act)
# Out:
# <AxesSubplot:xlabel='act_reconocida', ylabel='tBodyAcc-Mean-1'>

# %%
actividades.shape
# Out:
# (12, 3)

# %%
merged_inner = pd.merge(left=actividades,right=df1, left_on='act_reconocida', right_on='act_reconocida')
merged_inner
# Out:
#       act_reconocida       des_act     t_act  id_sub  tBodyAcc-Mean-1  \
# 0                  1       WALKING  Dinamica       1         0.040933
# 1                  1       WALKING  Dinamica       1         0.030375
# 2                  1       WALKING  Dinamica       1         0.029982
# 3                  1       WALKING  Dinamica       1         0.065674
# 4                  1       WALKING  Dinamica       1         0.038601
# ...              ...           ...       ...     ...              ...
# 7762              12  LIE_TO_STAND       NaN      28         0.746785
# 7763              12  LIE_TO_STAND       NaN      29         0.398618
# 7764              12  LIE_TO_STAND       NaN      29         0.585767
# 7765              12  LIE_TO_STAND       NaN      30         0.611205
# 7766              12  LIE_TO_STAND       NaN      30         0.607594
#
#       tBodyAcc-Mean-2  tBodyAcc-Mean-3  tBodyAcc-STD-1  tBodyAcc-STD-2  \
# ...

# %%
tip_a = merged_inner.groupby(by=["t_act",'des_act']).mean()
tip_a =tip_a.reset_index()

tip_a
# Out:
#       t_act             des_act  act_reconocida     id_sub  tBodyAcc-Mean-1  \
# 0  Dinamica             WALKING             1.0  16.462480         0.038610
# 1  Dinamica  WALKING_DOWNSTAIRS             3.0  17.089159         0.043449
# 2  Dinamica    WALKING_UPSTAIRS             2.0  16.992544         0.032830
# 3  Estatica              LAYING             6.0  18.009908         0.035454
# 4  Estatica             SITTING             4.0  18.061098         0.037438
# 5  Estatica            STANDING             5.0  17.766690         0.040014
#
#    tBodyAcc-Mean-2  tBodyAcc-Mean-3  tBodyAcc-STD-1  tBodyAcc-STD-2  \
# 0        -0.003473        -0.019730       -0.312709       -0.320093
# 1        -0.002116        -0.017834        0.139695       -0.251327
# 2        -0.012250        -0.027092       -0.221135       -0.306264
# 3        -0.004054        -0.018190       -0.955347       -0.953109
# 4         0.001972        -0.018468       -0.981788       -0.950845
# ...

# %%
tip_a.columns
# Out:
# Index(['t_act', 'des_act', 'act_reconocida', 'id_sub', 'tBodyAcc-Mean-1',
#        'tBodyAcc-Mean-2', 'tBodyAcc-Mean-3', 'tBodyAcc-STD-1',
#        'tBodyAcc-STD-2', 'tBodyAcc-STD-3',
#        ...
#        'fBodyGyroJerkMag-MeanFreq-1', 'fBodyGyroJerkMag-Skewness-1',
#        'fBodyGyroJerkMag-Kurtosis-1', 'tBodyAcc-AngleWRTGravity-1',
#        'tBodyAccJerk-AngleWRTGravity-1', 'tBodyGyro-AngleWRTGravity-1',
#        'tBodyGyroJerk-AngleWRTGravity-1', 'tXAxisAcc-AngleWRTGravity-1',
#        'tYAxisAcc-AngleWRTGravity-1', 'tZAxisAcc-AngleWRTGravity-1'],
#       dtype='object', length=565)

# %%
plt.figure(figsize=(5, 5))
x=tip_a.iloc[:, 0]
for y in 
y = tip_a.iloc[:, 4]#tip_a['tBodyAcc-Mean-1']
#filtered_data = data[(data['Word count'] <= 3500) & (data['# Shares'] <= 80000)]
 
colores=['orange','blue']
tamanios=[30,60]
sb.violinplot(x=x,y=y,data=fe_act)

# %%
print(tip_a.index)
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
plt.figure(figsize=(5, 5))

x=tip_a.iloc[:, 0]
n=4

for n in  tip_a.iloc[:, n]:
    n += 1
print(tip_a.iloc[:, n])
    #b.violinplot(x=x,y=y,data=fe_act) 
    
    
    #for x, col in enumerate(example.columns):
    for y, ind in enumerate(example.index):
        if example.loc[ind, col]:
            plt.plot(x, y, 'o', color='red')
            
    
    
    
    

colores=['orange','blue']
tamanios=[30,60]
#sb.violinplot(x=x,y=y,data=fe_act)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     753             try:
# --> 754                 self._validate_key(k, i)
#     755             except ValueError as err:
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1425         else:
# -> 1426             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#    1427
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12552/4110835924.py in <module>
# ...

# %%
tip_a.iloc[:, 4]
# Out:
# 0    0.038610
# 1    0.043449
# 2    0.032830
# 3    0.035454
# 4    0.037438
# 5    0.040014
# Name: tBodyAcc-Mean-1, dtype: float64

# %%
 
colores=['orange','blue']
tamanios=[30,60]

f1 = tip_a['t_act'].values
f2 = tip_a['tBodyAcc-Mean-1'].values
 
# Vamos a pintar en colores los puntos por debajo y por encima de la media de Cantidad de Palabras
asignar=[]
for index, row in tip_a.iterrows():
    if(row['tBodyAcc-Mean-1']< 0,1):
        asignar.append(colores[0])
    else:
        asignar.append(colores[1])
    
plt.scatter(f1, f2, c=asignar, s=tamanios[0])
plt.show()
